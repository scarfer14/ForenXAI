# %% [markdown]
# ### TODO: Synthetic Data Generation
# - [/] Load the cleaned NF-UNSW-NB15-v3 CSV and keep a lightweight schema dict (column → dtype) for validation.
# - [/] Configure an CTGAN model
# - [/] Generate ≥5k synthetic samples and persist them (e.g., `synthetic_df.to_csv(...)`) for downstream phases.

# %%
# REFERENCE: 
# https://www.youtube.com/watch?v=Ei0klF38CNs&t=319s
# https://colab.research.google.com/drive/18vavq2Kt8HqhSnZvvFxJUc-70NCPeDU_?usp=sharing#scrollTo=UZ9MM-vikDb2

# %%
https://colab.research.google.com/drive/1W7GlDR7BaVTGJw3nsOiy5Z699MbXMske?usp=sharing
