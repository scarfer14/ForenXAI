# %% [markdown]
# ### TODO: Model Evaluation
# - [ ] Run the locked model against the 15% hold-out set and capture accuracy/precision/recall/F1/ROC-AUC.
# - [ ] Plot confusion matrix + ROC curve (e.g., `ConfusionMatrixDisplay.from_estimator(...)`) to communicate performance quickly.
# - [ ] Summarize false-positive/false-negative patterns so product can tune thresholds.
# - [ ] Log action items or follow-ups (e.g., "need more benign traffic samples") before handing off to frontend.
# - [ ] Produce SHAP summary plots for the severity classifier so explainability artifacts accompany metrics (Tip: cache top tokens per class for the dashboard).
